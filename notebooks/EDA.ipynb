# %% [markdown]
# # Data Generated Analysis

# %%
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

GENERATED_ROOT_PATH = os.path.join("..", "input", "generated")
GENERATED_PAIRS_PATH = os.path.join(GENERATED_ROOT_PATH, "generated_pairs.csv")

# %%
df = pd.read_csv(GENERATED_PAIRS_PATH)

df.head()
# Out:
#   problem_id language      original_status  \
# 0     p00001      C++        Runtime Error
# 1     p00001      C++        Runtime Error
# 2     p00001      C++        Runtime Error
# 3     p00001      C++  Time Limit Exceeded
# 4     p00001      C++        Runtime Error
#
#                                         original_src  \
# 0  #include <algorithm>\n#include <cassert>\n#inc...
# 1  #include <stdio.h>\nint main(void) {\n  int i,...
# 2  #include <stdio.h>\n\nint main() {\n  int heig...
# 3  #include <algorithm>\n#include <iostream>\n#in...
# 4  #include <algorithm>\n#include <iostream>\n\nu...
#
#                                          changed_src   change  line
# 0  #include <algorithm>\n#include <cassert>\n#inc...  replace    49
# 1  #include <stdio.h>\nint main(void) {\n  int i,...  replace     4
# 2  #include <stdio.h>\n\nint main() {\n  int heig...  replace     7
# 3  #include <algorithm>\n#include <iostream>\n#in...  replace    12
# 4  #include <algorithm>\n#include <iostream>\n\nu...  replace    13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34798 entries, 0 to 34797
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   problem_id       34798 non-null  object
#  1   language         34798 non-null  object
#  2   original_status  34798 non-null  object
#  3   original_src     34798 non-null  object
#  4   changed_src      34798 non-null  object
#  5   change           34798 non-null  object
#  6   line             34798 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.9+ MB

# %%
sns.countplot(x=df["change"])

plt.title("Count plot of the change made from original src to changed src")
plt.show()

# %%
sns.displot(x=df[df["line"] <= 100]["line"])

plt.title("Count plot of the line that was changed")
plt.show()

# %%
sns.countplot(x=df["original_status"])

plt.title("Count plot of the original status")
plt.xticks(rotation=45)
plt.show()
