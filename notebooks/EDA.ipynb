# %% [markdown]
# # Data Generated Analysis

# %%
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

GENERATED_ROOT_PATH = os.path.join("..", "input", "generated")
GENERATED_PAIRS_PATH = os.path.join(GENERATED_ROOT_PATH, "generated_pairs.csv")

# %%
df = pd.read_csv(GENERATED_PAIRS_PATH)

df.head()
# Out:
#   problem_id language original_status  \
# 0     p00001      C++   Runtime Error
# 1     p00001      C++   Runtime Error
# 2     p00001      C++   Runtime Error
# 3     p00001      C++   Runtime Error
# 4     p00001      C++   Runtime Error
#
#                                         original_src  \
# 0  #include <bits/stdc++.h>\nusing namespace std;...
# 1  #include <algorithm>\n#include <iostream>\nusi...
# 2  #include <bits/stdc++.h>\nusing namespace std;...
# 3  #include <stdio.h>\nint main(void) {\n  int i,...
# 4  #include <stdio.h>\n\nint main() {\n  int heig...
#
#                                          changed_src   change  line error
# 0  #include <bits/stdc++.h>\nusing namespace std;...  replace     4   -11
# 1  #include <algorithm>\n#include <iostream>\nusi...  replace     9   -11
# 2  #include <bits/stdc++.h>\nusing namespace std;...  replace     4    -6
# 3  #include <stdio.h>\nint main(void) {\n  int i,...  replace     4   -11
# 4  #include <stdio.h>\n\nint main() {\n  int heig...  replace     7   -11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34663 entries, 0 to 34662
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   problem_id       34663 non-null  object
#  1   language         34663 non-null  object
#  2   original_status  34663 non-null  object
#  3   original_src     34663 non-null  object
#  4   changed_src      34663 non-null  object
#  5   change           34663 non-null  object
#  6   line             34663 non-null  int64
#  7   error            34663 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
sns.countplot(x=df["change"])

plt.title("Count plot of the change made from original src to changed src")
plt.show()

# %%
sns.displot(x=df[df["line"] <= 100]["line"])

plt.title("Count plot of the line that was changed")
plt.show()

# %%
sns.countplot(x=df["original_status"])

plt.title("Count plot of the original status")
plt.xticks(rotation=45)
plt.show()
